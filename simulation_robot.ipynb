# %%
import numpy as np
import torch.nn as nn
import gymnasium as gym
import gymnasium_robotics

# %%
gym.register_envs(gymnasium_robotics)

env = gym.make('FetchPickAndPlaceDense-v4', render_mode= "human")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 gym.register_envs(gymnasium_robotics)
# ----> 3 env = gym.make('FetchPickAndPlaceDense-v4', render_mode= "human")
#       4 env.render()
#
# File ~/.local/lib/python3.11/site-packages/gymnasium/envs/registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# --> 696     env_creator = load_env_creator(env_spec.entry_point)
#     698 # Determine if to use the rendering
#     699 render_modes: list[str] | None = None
#
# File ~/.local/lib/python3.11/site-packages/gymnasium/envs/registration.py:544, in load_env_creator(name)
#     535 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     536
#     537 Args:
#    (...)    541     The environment constructor for the given environment name.
#     542 """
#     543 mod_name, attr_name = name.split(":")
# --> 544 mod = importlib.import_module(mod_name)
#     545 fn = getattr(mod, attr_name)
#     546 return fn
#
# File /usr/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1128, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/__init__.py:1
# ----> 1 from gymnasium_robotics.envs.fetch.fetch_env import MujocoFetchEnv, MujocoPyFetchEnv
#
# File ~/.local/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/fetch_env.py:5
#       1 from typing import Union
#       3 import numpy as np
# ----> 5 from gymnasium_robotics.envs.robot_env import MujocoPyRobotEnv, MujocoRobotEnv
#       6 from gymnasium_robotics.utils import rotations
#       8 DEFAULT_CAMERA_CONFIG = {
#       9     "distance": 2.5,
#      10     "azimuth": 132.0,
#      11     "elevation": -14.0,
#      12     "lookat": np.array([1.3, 0.75, 0.55]),
#      13 }
#
# File ~/.local/lib/python3.11/site-packages/gymnasium_robotics/envs/robot_env.py:11
#       8 from gymnasium_robotics.core import GoalEnv
#      10 try:
# ---> 11     import mujoco_py
#      13     from gymnasium_robotics.utils import mujoco_py_utils
#      14 except ImportError as e:
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:508
#     504     return module.lib.__fun
#     507 mujoco_path = discover_mujoco()
# --> 508 cymj = load_cython_ext(mujoco_path)
#     511 # Trick to expose all mj* functions from mujoco in mujoco_py.*
#     512 class dict2(object):
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:111, in load_cython_ext(mujoco_path)
#     109             print("Import error. Trying to rebuild mujoco_py.")
#     110     if mod is None:
# --> 111         cext_so_path = builder.build()
#     112         mod = load_dynamic_ext('cymj', cext_so_path)
#     114 return mod
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:227, in MujocoExtensionBuilder.build(self)
#     226 def build(self):
# --> 227     built_so_file_path = self._build_impl()
#     228     new_so_file_path = self.get_so_file_path()
#     229     move(built_so_file_path, new_so_file_path)
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:282, in LinuxCPUExtensionBuilder._build_impl(self)
#     281 def _build_impl(self):
# --> 282     so_file_path = super()._build_impl()
#     283     # Removes absolute paths to libraries. Allows for dynamic loading.
#     284     fix_shared_library(so_file_path, 'libmujoco210.so', 'libmujoco210.so')
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:253, in MujocoExtensionBuilder._build_impl(self)
#     251 dist.parse_command_line()
#     252 obj_build_ext = dist.get_command_obj("build_ext")
# --> 253 dist.run_commands()
#     254 built_so_file_path, = obj_build_ext.get_outputs()
#     255 return built_so_file_path
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/dist.py:1002, in Distribution.run_commands(self)
#     997 """Run each command that was seen on the setup script command line.
#     998 Uses the list of commands found and cache of command objects
#     999 created by 'get_command_obj()'.
#    1000 """
#    1001 for cmd in self.commands:
# -> 1002     self.run_command(cmd)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/dist.py:1102, in Distribution.run_command(self, command)
#    1098 self.set_defaults()
#    1099 # Postpone defaults until all explicit configuration is considered
#    1100 # (setup() args, config files, command line and plugins)
# -> 1102 super().run_command(command)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/dist.py:1021, in Distribution.run_command(self, command)
#    1019 cmd_obj = self.get_command_obj(command)
#    1020 cmd_obj.ensure_finalized()
# -> 1021 cmd_obj.run()
#    1022 self.have_run[command] = True
#
# File ~/.local/lib/python3.11/site-packages/Cython/Distutils/old_build_ext.py:186, in old_build_ext.run(self)
#     182 if self.cython_gdb or [1 for ext in self.extensions
#     183                              if getattr(ext, 'cython_gdb', False)]:
#     184     optimization.disable_optimization()
# --> 186 _build_ext.build_ext.run(self)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:368, in build_ext.run(self)
#     365     self.compiler.set_link_objects(self.link_objects)
#     367 # Now actually compile and link everything.
# --> 368 self.build_extensions()
#
# File ~/.local/lib/python3.11/site-packages/mujoco_py/builder.py:150, in custom_build_ext.build_extensions(self)
#     148 except (AttributeError, ValueError):
#     149     pass
# --> 150 build_ext.build_extensions(self)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:484, in build_ext.build_extensions(self)
#     482     self._build_extensions_parallel()
#     483 else:
# --> 484     self._build_extensions_serial()
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:510, in build_ext._build_extensions_serial(self)
#     508 for ext in self.extensions:
#     509     with self._filter_build_errors(ext):
# --> 510         self.build_extension(ext)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:565, in build_ext.build_extension(self, ext)
#     562 for undef in ext.undef_macros:
#     563     macros.append((undef,))
# --> 565 objects = self.compiler.compile(
#     566     sources,
#     567     output_dir=self.build_temp,
#     568     macros=macros,
#     569     include_dirs=ext.include_dirs,
#     570     debug=self.debug,
#     571     extra_postargs=extra_args,
#     572     depends=ext.depends,
#     573 )
#     575 # XXX outdated variable, kept here in case third-part code
#     576 # needs it.
#     577 self._built_objects = objects[:]
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/compilers/C/base.py:655, in Compiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     653     except KeyError:
#     654         continue
# --> 655     self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     657 # Return *all* object filenames, not just the ones we just built.
#     658 return objects
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/compilers/C/unix.py:221, in Compiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     217         self.spawn(
#     218             compiler_so_cxx + cc_args + [src, '-o', obj] + extra_postargs
#     219         )
#     220     else:
# --> 221         self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#     222 except DistutilsExecError as msg:
#     223     raise CompileError(msg)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/compilers/C/base.py:1158, in Compiler.spawn(self, cmd, **kwargs)
#    1155 def spawn(
#    1156     self, cmd: MutableSequence[bytes | str | os.PathLike[str]], **kwargs
#    1157 ) -> None:
# -> 1158     spawn(cmd, dry_run=self.dry_run, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/setuptools/_distutils/spawn.py:87, in spawn(cmd, search_path, verbose, dry_run, env)
#      84         cmd[0] = executable
#      86 try:
# ---> 87     subprocess.check_call(cmd, env=_inject_macos_ver(env))
#      88 except OSError as exc:
#      89     raise DistutilsExecError(
#      90         f"command {_debug(cmd)!r} failed: {exc.args[-1]}"
#      91     ) from exc
#
# File /usr/lib/python3.11/subprocess.py:408, in check_call(*popenargs, **kwargs)
#     398 def check_call(*popenargs, **kwargs):
#     399     """Run command with arguments.  Wait for command to complete.  If
#     400     the exit code was zero then return, otherwise raise
#     401     CalledProcessError.  The CalledProcessError object will have the
#    (...)    406     check_call(["ls", "-l"])
#     407     """
# --> 408     retcode = call(*popenargs, **kwargs)
#     409     if retcode:
#     410         cmd = kwargs.get("args")
#
# File /usr/lib/python3.11/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File /usr/lib/python3.11/subprocess.py:1262, in Popen.wait(self, timeout)
#    1260     endtime = _time() + timeout
#    1261 try:
# -> 1262     return self._wait(timeout=timeout)
#    1263 except KeyboardInterrupt:
#    1264     # https://bugs.python.org/issue25942
#    1265     # The first keyboard interrupt waits briefly for the child to
#    1266     # exit under the common assumption that it also received the ^C
#    1267     # generated SIGINT and will exit rapidly.
#    1268     if timeout is not None:
#
# File /usr/lib/python3.11/subprocess.py:1997, in Popen._wait(self, timeout)
#    1995 if self.returncode is not None:
#    1996     break  # Another thread waited.
# -> 1997 (pid, sts) = self._try_wait(0)
#    1998 # Check the pid and loop as waitpid has been known to
#    1999 # return 0 even without WNOHANG in odd situations.
#    2000 # http://bugs.python.org/issue14396.
#    2001 if pid == self.pid:
#
# File /usr/lib/python3.11/subprocess.py:1955, in Popen._try_wait(self, wait_flags)
#    1953 """All callers to this function MUST hold self._waitpid_lock."""
#    1954 try:
# -> 1955     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1956 except ChildProcessError:
#    1957     # This happens if SIGCLD is set to be ignored or waiting
#    1958     # for child processes has otherwise been disabled for our
#    1959     # process.  This child is dead, we can't get the status.
#    1960     pid = self.pid
#
# KeyboardInterrupt:
